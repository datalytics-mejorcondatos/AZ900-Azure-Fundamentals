# %%
import pandas as pd
import requests
import io
from urllib.parse import urlencode

import sys
sys.path.append('c:\\Users\\nataly.ramirez\\AZ900-Azure-Fundamentals\\')
from analisisrentabilidades.procesamiento import limpieza_datos_retabilidades
from analisisrentabilidades.consultas import consultanit, result_rentabilidades

# %%
Lista_fondos = "https://www.bancolombia.com/consultarFondosInversion/rest/servicio/consultarListaFondos"
url_base =  "https://www.bancolombia.com/consultarFondosInversion/rest/servicio/buscarInformacionFondo/"

# %%
Nits= consultanit(Lista_fondos)
#Nits
# Out:
# 19
# 19

# %%
Fond= result_rentabilidades(url_base, lista_nits=Nits)
Fond
# Out:
# [{'nit': '900000528',
#   'nombre': 'Renta Acciones',
#   'calificacion': 'No Calificado',
#   'plazo': 'A la Vista',
#   'valorDeUnidad': '53.800,22',
#   'valorEnPesos': '$37,382,101,466.11',
#   'rentabilidad': {'dias': {'semanal': '163,51%',
#     'mensual': '28,75%',
#     'semestral': '-15,75%'},
#    'anios': {'anioCorrido': '-9,69%',
#     'ultimoAnio': '-9,71%',
#     'ultimos2Anios': '-5,93%',
#     'ultimos3Anios': '-6,71%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '800180687',
#   'nombre': 'Fiducuenta',
#   'calificacion': '(1/AAA)',
#   'plazo': 'A la Vista',
#   'valorDeUnidad': '33.003,97',
#   'valorEnPesos': '$11,665,327,967,974.86',
#   'rentabilidad': {'dias': {'semanal': '16,56%',
#     'mensual': '14,67%',
#     'semestral': '9,64%'},
#    'anios': {'anioCorrido': '6,60%',
#     'ultimoAnio': '6,61%',
#     'ultimos2Anios': '3,47%',
#     'ultimos3Anios': '3,43%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '901536211',
#   'nombre': 'Renta Alternativo Global',
#   'calificacion': 'No Calificado',
#   'plazo': 'Result=N/A',
#   'valorDeUnidad': '9.693,15',
#   'valorEnPesos': '$250,420,756,809.16',
#   'rentabilidad': {'dias': {'semanal': '-16,82%',
#     'mensual': '-3,88%',
#     'semestral': '0,00%'},
#    'anios': {'anioCorrido': 'N/A%',
#     'ultimoAnio': 'N/A%',
#     'ultimos2Anios': 'N/A%',
#     'ultimos3Anios': 'N/A%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '800244627',
#   'nombre': 'Fidurenta',
#   'calificacion': 'S3/AAAf(col)',
#   'plazo': '30 a 59 dÃ\xadas; 60 a 89 dÃ\xadas; 90 a 179dÃ\xadas; 180 a 359 dÃ\xadas; 360 dÃ\xadas en adelante.',
#   'valorDeUnidad': '36.686,10',
#   'valorEnPesos': '$347,277,160,329.93',
#   'rentabilidad': {'dias': {'semanal': '25,80%',
#     'mensual': '17,46%',
#     'semestral': '9,02%'},
#    'anios': {'anioCorrido': '4,72%',
#     'ultimoAnio': '4,71%',
#     'ultimos2Anios': '2,12%',
#     'ultimos3Anios': '3,44%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '901446225-3',
#   'nombre': 'Cerrado Renta Fija',
#   'calificacion': 'No Calificado',
#   'plazo': 'Result=N/A',
#   'valorDeUnidad': '10.597,55',
#   'valorEnPesos': '$.05-',
#   'rentabilidad': {'dias': {}, 'anios': {}},
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '9013917439',
#   'nombre': 'Renta Futuro',
#   'valorDeUnidad': '10,642.41',
#   'valorEnPesos': '$71,920,631,808.00',
#   'rentabilidad': {'dias': {'semanal': '24.83%',
#     'mensual': '10.11%',
#     'semestral': '10.91%'},
#    'anios': {'anioCorrido': '21.70%',
#     'ultimoAnio': '2.62%',
#     'ultimos2Anios': '1.08%',
#     'ultimos3Anios': '0.00%'}},
#   'fechaCierre': '20230301',
#   'sociedadAdministradora': 'Valores Bancolombia S.A.'},
#  {'nit': '9008966743',
#   'nombre': 'Renta Fija Plus',
#   'calificacion': 'S3/AAAf(col)',
#   'plazo': '30',
#   'valorDeUnidad': '15,006.55',
#   'valorEnPesos': '$263,279,804,416.00',
#   'rentabilidad': {'dias': {'semanal': '68.52%',
#     'mensual': '43.80%',
#     'semestral': '15.40%'},
#    'anios': {'anioCorrido': '30.71%',
#     'ultimoAnio': '6.03%',
#     'ultimos2Anios': '2.27%',
#     'ultimos3Anios': '4.26%'}},
#   'fechaCierre': '20230301',
#   'sociedadAdministradora': 'Valores Bancolombia S.A.'},
#  {'nit': '800227622',
#   'nombre': 'Plan Semilla',
#   'calificacion': '(3/AAA)',
#   'plazo': '1 aÂ¦o',
#   'valorDeUnidad': '23.333,14',
#   'valorEnPesos': '$639,838,832,581.00',
#   'rentabilidad': {'dias': {'semanal': '24,51%',
#     'mensual': '17,22%',
#     'semestral': '6,26%'},
#    'anios': {'anioCorrido': '1,96%',
#     'ultimoAnio': '1,95%',
#     'ultimos2Anios': '-0,17%',
#     'ultimos3Anios': '2,32%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '901574370-1',
#   'nombre': 'Cerrado Renta Fija III',
#   'calificacion': 'No Calificado',
#   'plazo': 'Result=N/A',
#   'valorDeUnidad': '10.301,66',
#   'valorEnPesos': '$42,600,979,594.50',
#   'rentabilidad': {'dias': {'semanal': '18,95%',
#     'mensual': '16,55%',
#     'semestral': 'N/A%'},
#    'anios': {'anioCorrido': 'N/A%',
#     'ultimoAnio': 'N/A%',
#     'ultimos2Anios': 'N/A%',
#     'ultimos3Anios': 'N/A%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '9004381462',
#   'nombre': 'Renta Liquidez',
#   'calificacion': 'S1/AAAf(col)',
#   'plazo': 'N/A',
#   'valorDeUnidad': '16,729.62',
#   'valorEnPesos': '$3,718,464,143,360.00',
#   'rentabilidad': {'dias': {'semanal': '33.50%',
#     'mensual': '24.74%',
#     'semestral': '14.48%'},
#    'anios': {'anioCorrido': '20.23%',
#     'ultimoAnio': '9.97%',
#     'ultimos2Anios': '5.42%',
#     'ultimos3Anios': '4.65%'}},
#   'fechaCierre': '20230301',
#   'sociedadAdministradora': 'Valores Bancolombia S.A.'},
#  {'nit': '901573146-3',
#   'nombre': 'Cerrado Renta Fija II',
#   'calificacion': 'No Calificado',
#   'plazo': 'Result=N/A',
#   'valorDeUnidad': '10.161,11',
#   'valorEnPesos': '$42,938,997,766.47',
#   'rentabilidad': {'dias': {'semanal': '28,63%',
#     'mensual': '18,21%',
#     'semestral': '4,44%'},
#    'anios': {'anioCorrido': 'N/A%',
#     'ultimoAnio': 'N/A%',
#     'ultimos2Anios': 'N/A%',
#     'ultimos3Anios': 'N/A%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '800241308',
#   'nombre': 'Renta Balanceado',
#   'calificacion': 'No Calificado',
#   'plazo': 'A la vista',
#   'valorDeUnidad': '14.761,09',
#   'valorEnPesos': '$88,245,748,062.02',
#   'rentabilidad': {'dias': {'semanal': '-3,49%',
#     'mensual': '-9,35%',
#     'semestral': '1,00%'},
#    'anios': {'anioCorrido': '-8,81%',
#     'ultimoAnio': '-8,85%',
#     'ultimos2Anios': '-1,43%',
#     'ultimos3Anios': '0,35%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '9006349247',
#   'nombre': 'Renta Sostenible Global',
#   'calificacion': 'N/A',
#   'plazo': 'N/A',
#   'valorDeUnidad': '31,382.49',
#   'valorEnPesos': '$285,904,601,088.00',
#   'rentabilidad': {'dias': {'semanal': '-64.11%',
#     'mensual': '20.56%',
#     'semestral': '18.42%'},
#    'anios': {'anioCorrido': '17.10%',
#     'ultimoAnio': '12.37%',
#     'ultimos2Anios': '10.41%',
#     'ultimos3Anios': '13.74%'}},
#   'fechaCierre': '20230301',
#   'sociedadAdministradora': 'Valores Bancolombia S.A.'},
#  {'nit': '9009585538',
#   'nombre': 'Renta Alta Convicción',
#   'calificacion': 'N/A',
#   'plazo': 'N/A',
#   'valorDeUnidad': '15,805.54',
#   'valorEnPesos': '$212,940,800,000.00',
#   'rentabilidad': {'dias': {'semanal': '-31.66%',
#     'mensual': '-23.04%',
#     'semestral': '12.09%'},
#    'anios': {'anioCorrido': '27.60%',
#     'ultimoAnio': '-2.22%',
#     'ultimos2Anios': '0.51%',
#     'ultimos3Anios': '6.79%'}},
#   'fechaCierre': '20230301',
#   'sociedadAdministradora': 'Valores Bancolombia S.A.'},
#  {'nit': '9012636163',
#   'nombre': 'FICI Sura AM Rentas Inmobiliarias',
#   'calificacion': 'No Calificado',
#   'plazo': 'N/A',
#   'valorDeUnidad': '12.583,16',
#   'valorEnPesos': '$447,784,076,714.12',
#   'rentabilidad': {'dias': {'semanal': '-1,43%',
#     'mensual': '6,55%',
#     'semestral': '1,97%'},
#    'anios': {'anioCorrido': '5,33%',
#     'ultimoAnio': '5,33%',
#     'ultimos2Anios': '4,54%',
#     'ultimos3Anios': '7,55%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '900237003',
#   'nombre': 'Fiduexcedentes',
#   'calificacion': ' (1/AAA)',
#   'plazo': 'A la vista',
#   'valorDeUnidad': '17.515,30',
#   'valorEnPesos': '$1,205,885,708,969.99',
#   'rentabilidad': {'dias': {'semanal': '17,17%',
#     'mensual': '14,89%',
#     'semestral': '9,50%'},
#    'anios': {'anioCorrido': '6,47%',
#     'ultimoAnio': '6,47%',
#     'ultimos2Anios': '3,45%',
#     'ultimos3Anios': '3,52%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '900000531',
#   'nombre': 'Renta Fija Plazo',
#   'calificacion': 'S5/AAAf(col)',
#   'plazo': 'N/A',
#   'valorDeUnidad': '28.270,90',
#   'valorEnPesos': '$155,647,204,627.17',
#   'rentabilidad': {'dias': {'semanal': '17,72%',
#     'mensual': '15,70%',
#     'semestral': '1,68%'},
#    'anios': {'anioCorrido': '-4,40%',
#     'ultimoAnio': '-4,43%',
#     'ultimos2Anios': '-4,55%',
#     'ultimos3Anios': '0,35%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A.'},
#  {'nit': '9004724683',
#   'nombre': 'Renta Variable Colombia',
#   'calificacion': 'N/A',
#   'plazo': 'N/A',
#   'valorDeUnidad': '10,912.18',
#   'valorEnPesos': '$114,539,790,336.00',
#   'rentabilidad': {'dias': {'semanal': '418.89%',
#     'mensual': '-53.52%',
#     'semestral': '-7.39%'},
#    'anios': {'anioCorrido': '-35.57%',
#     'ultimoAnio': '-21.33%',
#     'ultimos2Anios': '-6.07%',
#     'ultimos3Anios': '-6.63%'}},
#   'fechaCierre': '20230301',
#   'sociedadAdministradora': 'Valores Bancolombia S.A.'},
#  {'nit': '901574835-4',
#   'nombre': 'Fondo Cerrado Renta Fija IV',
#   'calificacion': 'No Calificado',
#   'plazo': 'Result=N/A',
#   'valorDeUnidad': '10.148,64',
#   'valorEnPesos': '$224,992,552,198.89',
#   'rentabilidad': {'dias': {'semanal': '16,49%',
#     'mensual': '15,30%',
#     'semestral': 'N/A%'},
#    'anios': {'anioCorrido': 'N/A%',
#     'ultimoAnio': 'N/A%',
#     'ultimos2Anios': 'N/A%',
#     'ultimos3Anios': 'N/A%'}},
#   'fechaCierre': '20221228',
#   'sociedadAdministradora': 'Fiduciaria Bancolombia S.A'}]

# %%
DFfondos= limpieza_datos_retabilidades(Fond)
DFfondos
# Out:
# c:\Users\nataly.ramirez\AZ900-Azure-Fundamentals\analisisrentabilidades\procesamiento.py:25: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   anual = Totaldf["rentabilidad"].apply(pd.Series).iloc[:,:4].copy()
# c:\Users\nataly.ramirez\AZ900-Azure-Fundamentals\analisisrentabilidades\procesamiento.py:25: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   anual = Totaldf["rentabilidad"].apply(pd.Series).iloc[:,:4].copy()
# c:\Users\nataly.ramirez\AZ900-Azure-Fundamentals\analisisrentabilidades\procesamiento.py:29: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   diarios = Totaldf["rentabilidad"].apply(pd.Series).iloc[:,4:].reset_index(drop=True).copy()
# c:\Users\nataly.ramirez\AZ900-Azure-Fundamentals\analisisrentabilidades\procesamiento.py:29: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   diarios = Totaldf["rentabilidad"].apply(pd.Series).iloc[:,4:].reset_index(drop=True).copy()
#             nit                             nombre   calificacion  \
# 0     900000528                     Renta Acciones  No Calificado
# 1     800180687                         Fiducuenta        (1/AAA)
# 2     901536211           Renta Alternativo Global  No Calificado
# 3     800244627                          Fidurenta   S3/AAAf(col)
# 4   901446225-3                 Cerrado Renta Fija  No Calificado
# 5    9013917439                       Renta Futuro            NaN
# 6    9008966743                    Renta Fija Plus   S3/AAAf(col)
# 7     800227622                       Plan Semilla        (3/AAA)
# 8   901574370-1             Cerrado Renta Fija III  No Calificado
# 9    9004381462                     Renta Liquidez   S1/AAAf(col)
# 10  901573146-3              Cerrado Renta Fija II  No Calificado
# 11    800241308                   Renta Balanceado  No Calificado
# 12   9006349247            Renta Sostenible Global            N/A
# 13   9009585538              Renta Alta Convicción            N/A
# 14   9012636163  FICI Sura AM Rentas Inmobiliarias  No Calificado
# 15    900237003                     Fiduexcedentes        (1/AAA)
# 16    900000531                   Renta Fija Plazo   S5/AAAf(col)
# 17   9004724683            Renta Variable Colombia            N/A
# 18  901574835-4        Fondo Cerrado Renta Fija IV  No Calificado
#
#                                                 plazo valorDeUnidad  \
# 0                                          A la Vista     53.800,22
# 1                                          A la Vista     33.003,97
# 2                                          Result=N/A      9.693,15
# 3   30 a 59 dÃ­as; 60 a 89 dÃ­as; 90 a 179dÃ­as; 1...     36.686,10
# 4                                          Result=N/A     10.597,55
# 5                                                 NaN     10,642.41
# 6                                                  30     15,006.55
# 7                                              1 aÂ¦o     23.333,14
# 8                                          Result=N/A     10.301,66
# 9                                                 N/A     16,729.62
# 10                                         Result=N/A     10.161,11
# 11                                         A la vista     14.761,09
# 12                                                N/A     31,382.49
# 13                                                N/A     15,805.54
# 14                                                N/A     12.583,16
# 15                                         A la vista     17.515,30
# 16                                                N/A     28.270,90
# 17                                                N/A     10,912.18
# 18                                         Result=N/A     10.148,64
#
#               valorEnPesos fechaCierre       sociedadAdministradora  \
# 0       $37,382,101,466.11    20221228  Fiduciaria Bancolombia S.A.
# 1   $11,665,327,967,974.86    20221228  Fiduciaria Bancolombia S.A.
# 2      $250,420,756,809.16    20221228  Fiduciaria Bancolombia S.A.
# 3      $347,277,160,329.93    20221228  Fiduciaria Bancolombia S.A.
# 4                    $.05-         NaN  Fiduciaria Bancolombia S.A.
# 5       $71,920,631,808.00    20230301     Valores Bancolombia S.A.
# 6      $263,279,804,416.00    20230301     Valores Bancolombia S.A.
# 7      $639,838,832,581.00    20221228  Fiduciaria Bancolombia S.A.
# 8       $42,600,979,594.50    20221228  Fiduciaria Bancolombia S.A.
# 9    $3,718,464,143,360.00    20230301     Valores Bancolombia S.A.
# 10      $42,938,997,766.47    20221228  Fiduciaria Bancolombia S.A.
# 11      $88,245,748,062.02    20221228  Fiduciaria Bancolombia S.A.
# 12     $285,904,601,088.00    20230301     Valores Bancolombia S.A.
# 13     $212,940,800,000.00    20230301     Valores Bancolombia S.A.
# 14     $447,784,076,714.12    20221228  Fiduciaria Bancolombia S.A.
# 15   $1,205,885,708,969.99    20221228  Fiduciaria Bancolombia S.A.
# 16     $155,647,204,627.17    20221228  Fiduciaria Bancolombia S.A.
# 17     $114,539,790,336.00    20230301     Valores Bancolombia S.A.
# 18     $224,992,552,198.89    20221228   Fiduciaria Bancolombia S.A
#
#    anioCorrido ultimoAnio ultimos2Anios ultimos3Anios  semanal  mensual  \
# 0       -9,69%     -9,71%        -5,93%        -6,71%  163,51%   28,75%
# 1        6,60%      6,61%         3,47%         3,43%   16,56%   14,67%
# 2         N/A%       N/A%          N/A%          N/A%  -16,82%   -3,88%
# 3        4,72%      4,71%         2,12%         3,44%   25,80%   17,46%
# 4       21.70%      2.62%         1.08%         0.00%   24.83%   10.11%
# 5       30.71%      6.03%         2.27%         4.26%   68.52%   43.80%
# 6        1,96%      1,95%        -0,17%         2,32%   24,51%   17,22%
# 7         N/A%       N/A%          N/A%          N/A%   18,95%   16,55%
# 8       20.23%      9.97%         5.42%         4.65%   33.50%   24.74%
# 9         N/A%       N/A%          N/A%          N/A%   28,63%   18,21%
# 10      -8,81%     -8,85%        -1,43%         0,35%   -3,49%   -9,35%
# 11      17.10%     12.37%        10.41%        13.74%  -64.11%   20.56%
# 12      27.60%     -2.22%         0.51%         6.79%  -31.66%  -23.04%
# 13       5,33%      5,33%         4,54%         7,55%   -1,43%    6,55%
# 14       6,47%      6,47%         3,45%         3,52%   17,17%   14,89%
# 15      -4,40%     -4,43%        -4,55%         0,35%   17,72%   15,70%
# 16     -35.57%    -21.33%        -6.07%        -6.63%  418.89%  -53.52%
# 17        N/A%       N/A%          N/A%          N/A%   16,49%   15,30%
# 18         NaN        NaN           NaN           NaN      NaN      NaN
#
#    semestral
# 0    -15,75%
# 1      9,64%
# 2      0,00%
# 3      9,02%
# 4     10.91%
# 5     15.40%
# 6      6,26%
# 7       N/A%
# 8     14.48%
# 9      4,44%
# 10     1,00%
# 11    18.42%
# 12    12.09%
# 13     1,97%
# 14     9,50%
# 15     1,68%
# 16    -7.39%
# 17      N/A%
# 18       NaN

# %%
ruta= 'Fondos.csv'
Archivo1= DFfondos.to_csv(ruta, index=False)
Archivo1
